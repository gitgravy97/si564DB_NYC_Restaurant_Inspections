# %% [markdown]
# # Dump sample of dataframe

# %%
import pandas as pd

# %%
df = pd.read_csv('data/DOHMH_NYC_Restaurant_Inspection_Results.csv')

# %%
sample = df.sample(25000).set_index("CAMIS")
sample
# Out:
#                                      DBA       BORO BUILDING  \
# CAMIS
# 50003500                 LUI'S THAI FOOD  Manhattan      128
# 50090591                     AIYARA THAI  Manhattan      480
# 50035344     RADHUNI SWEETS & RESTAURANT   Brooklyn      483
# 50059605               THE KING OF TACOS     Queens     9017
# 41476697  VIEW OF THE WORLD TERRACE CLUB  Manhattan      140
# ...                                  ...        ...      ...
# 50070258            MAMA'S FRIED CHICKEN  Manhattan     2925
# 50059826                      MCDONALD'S     Queens     9118
# 50050205         SO GONG DONG TOFU HOUSE     Queens    14906
# 41690737                            TAIM  Manhattan       45
# 50081167                  LE CAFE COFFEE  Manhattan      407
#
#                      STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# CAMIS
# 50003500   EAST    4 STREET  10003.0  6466699310                Thai
# 50090591           9 AVENUE  10018.0  2125641822                Thai
# 50035344    MCDONALD AVENUE  11218.0  7189720072         Bangladeshi
# 50059605           31ST AVE  11369.0  7184240299             Tex-Mex
# 41476697  WASHINGTON STREET  10006.0  6467463200            American
# ...                     ...      ...         ...                 ...
# 50070258           8 AVENUE  10039.0  2122899028             Chicken
# 50059826   BEACH CHANNEL DR  11693.0  7184744949          Hamburgers
# 50050205           41ST AVE  11355.0  7183210220              Korean
# 41690737      SPRING STREET  10012.0  2122190600       Mediterranean
# 50081167         PARK AVE S  10016.0  6174477811     Café/Coffee/Tea
#
#          INSPECTION DATE                                             ACTION  \
# CAMIS
# 50003500      07/12/2017  Establishment Closed by DOHMH.  Violations wer...
# 50090591      01/27/2020    Violations were cited in the following area(s).
# 50035344      03/26/2019    Violations were cited in the following area(s).
# 50059605      04/01/2017    Violations were cited in the following area(s).
# 41476697      01/29/2020    Violations were cited in the following area(s).
# ...                  ...                                                ...
# 50070258      07/25/2018    Violations were cited in the following area(s).
# 50059826      12/13/2018    Violations were cited in the following area(s).
# 50050205      01/23/2020    Violations were cited in the following area(s).
# 41690737      11/15/2017    Violations were cited in the following area(s).
# 50081167      09/11/2019    Violations were cited in the following area(s).
#
#          VIOLATION CODE  ... RECORD DATE  \
# CAMIS                    ...
# 50003500            05F  ...  03/12/2021
# 50090591            10E  ...  03/12/2021
# 50035344            02G  ...  03/12/2021
# 50059605            06C  ...  03/12/2021
# 41476697            08A  ...  03/12/2021
# ...                 ...  ...         ...
# 50070258            10F  ...  03/12/2021
# 50059826            06A  ...  03/12/2021
# 50050205            09B  ...  03/12/2021
# 41690737            04M  ...  03/12/2021
# 50081167            06D  ...  03/12/2021
#
#                                         INSPECTION TYPE   Latitude  Longitude  \
# CAMIS
# 50003500               Cycle Inspection / Re-inspection  40.725359 -73.987484
# 50090591          Cycle Inspection / Initial Inspection  40.755156 -73.995001
# 50035344               Cycle Inspection / Re-inspection  40.642246 -73.979324
# 50059605  Pre-permit (Operational) / Initial Inspection  40.760041 -73.878349
# 41476697          Cycle Inspection / Initial Inspection  40.709722 -74.013818
# ...                                                 ...        ...        ...
# 50070258       Pre-permit (Operational) / Re-inspection  40.829061 -73.937353
# 50059826               Cycle Inspection / Re-inspection  40.588907 -73.816468
# 50050205          Cycle Inspection / Initial Inspection  40.762136 -73.815562
# 41690737          Cycle Inspection / Initial Inspection  40.721876 -73.996078
# 50081167          Cycle Inspection / Initial Inspection  40.743317 -73.983695
#
#          Community Board Council District Census Tract        BIN  \
# CAMIS
# 50003500           103.0              2.0       3800.0  1006176.0
# 50090591           104.0              3.0      11100.0  1013609.0
# 50035344           312.0             39.0      48600.0  3125295.0
# 50059605           403.0             22.0      35100.0  4445870.0
# 41476697           101.0              1.0       1300.0  1001063.0
# ...                  ...              ...          ...        ...
# 50070258           110.0              9.0      23502.0  1060901.0
# 50059826           414.0             32.0      94202.0  4303337.0
# 50050205           407.0             20.0     116700.0  4533261.0
# 41690737           102.0              1.0       4300.0  1075962.0
# 50081167           105.0              2.0       7200.0  1018204.0
#
#                    BBL   NTA
# CAMIS
# 50003500  1.004450e+09  MN22
# 50090591  1.007600e+09  MN13
# 50035344  3.053530e+09  BK41
# 50059605  4.013880e+09  QN28
# 41476697  1.000560e+09  MN25
# ...                ...   ...
# 50070258  1.020470e+09  MN03
# 50059826  4.161090e+09  QN12
# 50050205  4.050540e+09  QN51
# 41690737  1.004948e+09  MN24
# 50081167  1.008840e+09  MN20
#
# [25000 rows x 25 columns]

# %%
sample.to_csv(f"./sample25k.csv")
